# %%
import pandas as pd
new_reviews = pd.read_excel (r'C:\\Users\\ilans\\Documents\\Studies\\Semester 5\\Final Project\\\Reviews\\categories4.xlsx')
NR=new_reviews.head()
topics=["cleanliness","food","service","location","general","room","price"]

# %%
topics=["cleanliness","food","service","location","general","room","price"]

# %%
Cleanliness=["clean","dirty","made","floor","sheet","smell","stain"]
Food=["tasty","delicious","dinner","lunch","breakfast","drink","meal","course","italian","laffa","bar","restaurant","cafe","buffet","kitchen","chef","dining","pretzel","beer","water","pizza","help","coffee"]
Service=["staff","friendly","carlos","early","aaron","complimentary","rafael","reservation","movie","late","margaret","hospitality","steven","welcome","hector","knowledgable","arlo","aziz","jamie","stewart","reception","king","brynn","team","checkin","gigi","order","quick","kiki","rosarrio","appreciated","service","peter","concierge","professional","mai","sami","alex","front","host"]
Price=["vlaue","money","pricy","expensive","cheap","rate","offer","discount","check","credit"]
Room=["bed","window","table","chair","furniture","toilet","room","bath","comfort","suite","cabin","wall","shower","look","warm","wifi","inviting","candy","small","big","phone","picture"]
Location=["view","sea","ocean","city","center","central","park","manhattan","location","within","street","train","hudson","square","walk","place","island","river","nyc","southern","local","spot","metro","close","village","washington","station","located"]
General=["general","don't","hotel","terrible","aka","excellent","visit","stay","great","always","helped","new","well","got","next","give","every","copy","nice","exactly","time","11am","star","bit","good","night","experience","elevator","around","extremely","especially","hot","cold","little","pretty","manager","people","get","boat","tell","really","minute","list","problem","bet","last","thank","could","trip","area","went","minute","definitely","perfect","really","including","almost","2","two","already","7","first","access","mind","lovely","amazing","best","also","lovely","partner","back","cheer","would","vibe","fianc","standard","love","week","person","sister","addition"]

# %%
def exists(array,value):
    for i in range(len(array)):
        if(value.find(array[i])!=-1):
            print(value)
            return 0
    return 1
def replace(array,value,name):
    if(exists(array,value)==0):
        value=name;
        print (value)

# %%
new_reviews.to_excel('C:\\Users\\ilans\\Documents\\Studies\\Semester 5\\Final Project\\\Reviews\\categories4.xlsx')

# %%
cnt=0
for i in range(len(new_reviews["subject1"])):
    if(exists(Cleanliness,new_reviews["subject1"][i])and
    exists(Food,new_reviews["subject1"][i])and
      exists(Service,new_reviews["subject1"][i])and
      exists(Price,new_reviews["subject1"][i])and
      exists(Room,new_reviews["subject1"][i])and
      exists(Location,new_reviews["subject1"][i])and
      exists(General,new_reviews["subject1"][i])):
        cnt=cnt+1
        print(new_reviews["subject1"][i])
print(cnt)
# Out:
# general
# location
# general
# room
# room
# general
# general
# location
# general
# room
# location
# service
# location
# general
# location
# general
# food
# general
# general
# general
# location
# location
# general
# service
# general
# cleanliness
# general
# location
# room
# general
# general
# general
# location
# general
# general
# general
# general
# general
# general
# general
# "price"
# general
# general
# general
# room
# general
# general
# general
# general
# general
# room
# "price"
# room
# general
# food
# room
# room
# general
# location
# general
# room
# location
# "need"
# general
# room
# "it"
# food
# general
# location
# room
# service
# service
# room
# location
# general
# "def"
# general
# general
# general
# general
# room
# "way"
# room
# room
# "pandemic"
# general
# "control"
# room
# general
# "gm"
# food
# general
# general
# service
# general
# room
# general
# room
# room
# general
# room
# room
# general
# general
# general
# general
# ...

# %%
print(new_reviews["subject1"])
# Out:
# 0        "terrible"
# 1          location
# 2             "aka"
# 3              room
# 4              room
#             ...
# 40203         "got"
# 40204          room
# 40205        "walk"
# 40206       "great"
# 40207       "cabin"
# Name: subject1, Length: 40208, dtype: object

# %%
value
# Out:
# 'bedroom'

# %%
cnt=0
to_run=new_reviews["subject4"]
for i in range(len(to_run)):
    if(exists(Cleanliness,to_run[i])==0):
        to_run[i]="cleanliness"
        print("replaced with:cleanliness")
        cnt=cnt+1
    if(exists(Food,to_run[i])==0):
        to_run[i]="food"
        print("replaced with:food")
        cnt=cnt+1
    if(exists(Service,to_run[i])==0):
        to_run[i]="service"
        print("replaced with:service")
        cnt=cnt+1
    if(exists(Price,to_run[i])==0):
        to_run[i]="price"
        print("replaced with:price")
        cnt=cnt+1
    if(exists(Room,to_run[i])==0):
        to_run[i]="room"
        print("replaced with:room")
        cnt=cnt+1
    if(exists(Location,to_run[i])==0):
        to_run[i]="location"
        print("replaced with:location")
        cnt=cnt+1
    if(exists(General,to_run[i])==0):
        to_run[i]="general"
        print("replaced with:general")
        cnt=cnt+1
cnt
# Out:
# service
# replaced with:service
# general
# replaced with:general
# room
# replaced with:room
# room
# replaced with:room
# general
# replaced with:general
# general
# replaced with:general
# general
# replaced with:general
# general
# replaced with:general
# room
# replaced with:room
# service
# replaced with:service
# location
# replaced with:location
# location
# replaced with:location
# location
# replaced with:location
# general
# replaced with:general
# general
# replaced with:general
# general
# replaced with:general
# general
# replaced with:general
# general
# replaced with:general
# general
# replaced with:general
# service
# replaced with:service
# general
# replaced with:general
# room
# replaced with:room
# general
# replaced with:general
# location
# replaced with:location
# room
# replaced with:room
# location
# replaced with:location
# general
# replaced with:general
# general
# replaced with:general
# location
# replaced with:location
# general
# ...

# %%
new_reviews["subject4"]=to_run

# %%
filtered = pd.read_excel ('C:\\Users\\ilans\\Documents\\Studies\\Semester 5\\Final Project\\\Reviews\\categories3.xlsx')

# %%
import excel2json

excel2json.convert_from_file(r'C:\\Users\\ilans\\Documents\\Studies\\Semester 5\\Final Project\\\Reviews\\categories3.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-133-681e6a9d9719> in <module>
# ----> 1 import excel2json
#       2
#       3 excel2json.convert_from_file(r'C:\\Users\\ilans\\Documents\\Studies\\Semester 5\\Final Project\\\Reviews\\categories3.xlsx')
#
# ModuleNotFoundError: No module named 'excel2json'
